# %%
# !pip install ydata_profiling==4.9.0

# %%
pip install ipywidgets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sweetviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from scipy.stats import zscore
import sweetviz as sv


from ydata_profiling import ProfileReport
# Out:
# /Users/wadiahalbuhairi/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("data_saudi_used_cars.csv")
dt = pd.read_csv("data_saudi_used_cars.csv")

# %%
dt = dt[dt["Make"] == "Classic"]
dt
# Out:
#          Type  Region     Make  Gear_Type Origin Options  Year  Engine_Size  \
# 883  Cadillac  Riyadh  Classic  Automatic  Saudi    Full  1995          8.0
#
#      Mileage  Negotiable  Price
# 883      119       False  25000

# %% [markdown]
# # Data Profiling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5624 entries, 0 to 5623
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         5624 non-null   object
#  1   Region       5624 non-null   object
#  2   Make         5624 non-null   object
#  3   Gear_Type    5624 non-null   object
#  4   Origin       5624 non-null   object
#  5   Options      5624 non-null   object
#  6   Year         5624 non-null   int64
#  7   Engine_Size  5624 non-null   float64
#  8   Mileage      5624 non-null   int64
#  9   Negotiable   5624 non-null   bool
#  10  Price        5624 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 445.0+ KB

# %%
df.sample(5)
# Out:
#          Type  Region    Make  Gear_Type Origin    Options  Year  Engine_Size  \
# 1048    Camry  Riyadh  Toyota  Automatic  Saudi   Standard  2017          2.4
# 5317      CX3  Riyadh   Mazda  Automatic  Saudi  Semi Full  2019          2.0
# 1957    Hilux  Jeddah  Toyota     Manual  Saudi       Full  1995          2.7
# 3547  Corolla  Riyadh  Toyota  Automatic  Saudi       Full  2020          1.6
# 1941    Pilot  Dammam   Honda  Automatic  Other  Semi Full  2005          6.0
#
#       Mileage  Negotiable  Price
# 1048    97000       False  68000
# 5317    49000        True      0
# 1957   900000       False  14000
# 3547    58000       False  65000
# 1941     4130       False  15000

# %%
df.shape
# Out:
# (5624, 11)

# %%
profile = ProfileReport(df, title="Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.9.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-08-07 17:41:42.506970&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Relavance

# %%
df.drop(["Negotiable"], axis=1, inplace = True)

# %%
df.columns
# Out:
# Index(['Type', 'Region', 'Make', 'Gear_Type', 'Origin', 'Options', 'Year',
#        'Engine_Size', 'Mileage', 'Price'],
#       dtype='object')

# %% [markdown]
# ## Uniqueness

# %%
# Check duplicates row
df[df.duplicated()]
# Out:
#         Type  Region     Make  Gear_Type Origin   Options  Year  Engine_Size  \
# 953      Rio  Riyadh      Kia  Automatic  Saudi  Standard  2016          1.4
# 4646  Sonata  Jeddah  Hyundai  Automatic  Saudi  Standard  2020          2.4
# 4933  Tucson  Dammam  Hyundai  Automatic  Saudi  Standard  2016          2.0
# 5267   Camry  Riyadh   Toyota  Automatic  Saudi      Full  2013          2.5
#
#       Mileage  Price
# 953    270000  25000
# 4646      100  72910
# 4933   155000  45000
# 5267   185000      0

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5620, 10)

# %% [markdown]
# ## Completeness

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Type           0
# Region         0
# Make           0
# Gear_Type      0
# Origin         0
# Options        0
# Year           0
# Engine_Size    0
# Mileage        0
# Price          0
# dtype: int64

# %%
df["Make"].unique()
# Out:
# array(['Toyota', 'GMC', 'Land Rover', 'Kia', 'Mazda', 'Porsche',
#        'Hyundai', 'Lexus', 'Chrysler', 'Chevrolet', 'Nissan',
#        'Mitsubishi', 'Ford', 'MG', 'Mercedes', 'Jeep', 'BMW', 'Audi',
#        'Lincoln', 'Cadillac', 'Genesis', 'Renault', 'Honda', 'Suzuki',
#        'Zhengzhou', 'Dodge', 'HAVAL', 'INFINITI', 'Isuzu', 'Changan',
#        'Aston Martin', 'Mercury', 'Great Wall', 'Other', 'Rolls-Royce',
#        'MINI', 'Volkswagen', 'BYD', 'Geely', 'Victory Auto', 'Classic',
#        'Jaguar', 'Daihatsu', 'Maserati', 'Hummer', 'GAC', 'Lifan',
#        'Bentley', 'Chery', 'Peugeot', 'Foton', 'Škoda', 'Fiat', 'Iveco',
#        'SsangYong', 'FAW', 'Tata', 'Ferrari'], dtype=object)

# %%
# Change make to Cadillac if make is Classic usnig Lambda
df["Make"] = df["Make"].map(lambda x : 'Cadillac' if x == 'Classic' else x)

df[df["Make"] == 'Classic']
# Out:
# Empty DataFrame
# Columns: [Type, Region, Make, Gear_Type, Origin, Options, Year, Engine_Size, Mileage, Price]
# Index: []

# %%
df["Type"] = df["Type"].map(lambda x : 'Classic' if x == 'Cadillac' else x)

df[df["Type"] == 'Classic']
# Out:
#         Type  Region      Make  Gear_Type Origin Options  Year  Engine_Size  \
# 883  Classic  Riyadh  Cadillac  Automatic  Saudi    Full  1995          8.0
#
#      Mileage  Price
# 883      119  25000

# %% [markdown]
# ## 1. Univariate Graphical Analysis

# %% [markdown]
# report = sv.analyze(df)

# %%
df['z_score'] = (df['Mileage'] - df['Mileage'].mean()) / df['Mileage'].std()
df = df[df['z_score'].abs() < 3]  # Typically, a Z-score greater than 3 is considered an outlier

df.shape
# Out:
# (5592, 11)

# %%
df_2019 = df[(df['Year'] == 2019) & (df['Price'] > 0)]
df_2019.describe()
# Out:
#          Year  Engine_Size        Mileage          Price     z_score
# count   360.0   360.000000     360.000000     360.000000  360.000000
# mean   2019.0     2.606389   60400.230556  103664.283333   -0.236373
# std       0.0     1.294358   32557.397642  103676.925282    0.085014
# min    2019.0     1.000000     107.000000       1.000000   -0.393811
# 25%    2019.0     1.500000   38000.000000   40000.000000   -0.294864
# 50%    2019.0     2.000000   56995.500000   71250.000000   -0.245263
# 75%    2019.0     3.500000   84000.000000  130000.000000   -0.174748
# max    2019.0     8.000000  178000.000000  850000.000000    0.070706

# %%
df_2019
# Out:
#               Type  Region     Make  Gear_Type Origin    Options  Year  \
# 5              CX3    Abha    Mazda  Automatic  Saudi  Semi Full  2019
# 17    Land Cruiser  Riyadh   Toyota  Automatic  Saudi       Full  2019
# 51           The 5  Jeddah      BMW  Automatic  Saudi   Standard  2019
# 73    Land Cruiser  Qassim   Toyota  Automatic  Saudi       Full  2019
# 84             G80  Riyadh  Genesis  Automatic  Saudi  Semi Full  2019
# ...            ...     ...      ...        ...    ...        ...   ...
# 5547        Optima  Qassim      Kia  Automatic  Saudi   Standard  2019
# 5577        Taurus  Riyadh     Ford  Automatic  Saudi   Standard  2019
# 5579        Accent  Riyadh  Hyundai  Automatic  Saudi   Standard  2019
# 5608      Sportage  Jeddah      Kia  Automatic  Saudi  Semi Full  2019
# 5611      Sportage  Khobar      Kia  Automatic  Saudi   Standard  2019
#
#       Engine_Size  Mileage   Price   z_score
# 5             2.0    25000   58000 -0.328810
# ...

# %%
df_2019
# Out:
#               Type  Region     Make  Gear_Type Origin    Options  Year  \
# 5              CX3    Abha    Mazda  Automatic  Saudi  Semi Full  2019
# 17    Land Cruiser  Riyadh   Toyota  Automatic  Saudi       Full  2019
# 51           The 5  Jeddah      BMW  Automatic  Saudi   Standard  2019
# 73    Land Cruiser  Qassim   Toyota  Automatic  Saudi       Full  2019
# 84             G80  Riyadh  Genesis  Automatic  Saudi  Semi Full  2019
# ...            ...     ...      ...        ...    ...        ...   ...
# 5547        Optima  Qassim      Kia  Automatic  Saudi   Standard  2019
# 5577        Taurus  Riyadh     Ford  Automatic  Saudi   Standard  2019
# 5579        Accent  Riyadh  Hyundai  Automatic  Saudi   Standard  2019
# 5608      Sportage  Jeddah      Kia  Automatic  Saudi  Semi Full  2019
# 5611      Sportage  Khobar      Kia  Automatic  Saudi   Standard  2019
#
#       Engine_Size  Mileage   Price   z_score
# 5             2.0    25000   58000 -0.328810
# ...

# %%
report2019
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 report2019
#
# NameError: name 'report2019' is not defined

# %%
df_2019
# Out:
#               Type  Region     Make  Gear_Type Origin    Options  Year  \
# 5              CX3    Abha    Mazda  Automatic  Saudi  Semi Full  2019
# 17    Land Cruiser  Riyadh   Toyota  Automatic  Saudi       Full  2019
# 51           The 5  Jeddah      BMW  Automatic  Saudi   Standard  2019
# 73    Land Cruiser  Qassim   Toyota  Automatic  Saudi       Full  2019
# 84             G80  Riyadh  Genesis  Automatic  Saudi  Semi Full  2019
# ...            ...     ...      ...        ...    ...        ...   ...
# 5547        Optima  Qassim      Kia  Automatic  Saudi   Standard  2019
# 5577        Taurus  Riyadh     Ford  Automatic  Saudi   Standard  2019
# 5579        Accent  Riyadh  Hyundai  Automatic  Saudi   Standard  2019
# 5608      Sportage  Jeddah      Kia  Automatic  Saudi  Semi Full  2019
# 5611      Sportage  Khobar      Kia  Automatic  Saudi   Standard  2019
#
#       Engine_Size  Mileage   Price   z_score
# 5             2.0    25000   58000 -0.328810
# ...

# %% [markdown]
# # Finished Cleaning

# %%
report = sv.analyze(df)
report.show_html("sweetviz_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
report2019 = sv.analyze(df_2019)
report2019.show_html("sweetviz2019_updated_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweetviz2019_updated_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1d0bd6f5-b42c-4a1c-864b-daeaa10057d5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
